# %% [markdown]
# # word2vec: How To Prep Word Vectors For Modeling

# %% [markdown]
# ### Train Our Own Model

# %%
# Read in the data, clean it, split it into train and test sets, and then train a word2vec model
import gensim
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
pd.set_option('display.max_colwidth', 100)

messages = pd.read_csv('../../../data/spam.csv', encoding='latin-1')
messages = messages.drop(labels = ["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis = 1)
messages.columns = ["label", "text"]


messages['text_clean'] = messages['text'].apply(lambda x: gensim.utils.simple_preprocess(x))
X_train, X_test, y_train, y_test = train_test_split(messages['text_clean'],
                                                    messages['label'], test_size=0.2)

w2v_model = gensim.models.Word2Vec(X_train,
                                   vector_size=100,
                                   window=5,
                                   min_count=2)

# %%
messages.shape
messages.head()
# Out:
#   label  \
# 0   ham
# 1   ham
# 2  spam
# 3   ham
# 4   ham
#
#                                                                                                   text  \
# 0  Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there g...
# 1                                                                        Ok lar... Joking wif u oni...
# 2  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 3                                                    U dun say so early hor... U c already then say...
# 4                                        Nah I don't think he goes to usf, he lives around here though
#
#                                                                                             text_clean
# 0  [go, until, jurong, point, crazy, available, only, in, bugis, great, world, la, buffet, cine, th...
# 1                                                                          [ok, lar, joking, wif, oni]
# 2  [free, entry, in, wkly, comp, to, win, fa, cup, final, tkts, st, may, text, fa, to, to, receive,...
# 3                                                       [dun, say, so, early, hor, already, then, say]
# 4                                [nah, don, think, he, goes, to, usf, he, lives, around, here, though]

# %% [markdown]
# ### Prep Word Vectors

# %%
# Generate a list of words the word2vec model learned word vectors for
w2v_model.wv.index_to_key
# Out:
# ['you',
#  'to',
#  'the',
#  'and',
#  'in',
#  'is',
#  'me',
#  'it',
#  'my',
#  'for',
#  'your',
#  'of',
#  'call',
#  'that',
#  'have',
#  'on',
#  'now',
#  'are',
#  'can',
#  'but',
#  'not',
#  'so',
#  'or',
#  'do',
#  'at',
#  'we',
#  'get',
#  'with',
#  'be',
#  'ur',
#  'no',
#  'if',
#  'will',
#  'just',
#  'this',
#  'how',
#  'gt',
#  'lt',
#  'when',
#  'from',
#  'ok',
#  'up',
#  'free',
#  'what',
#  'go',
#  'all',
#  'll',
#  'out',
#  'know',
#  'am',
#  'day',
#  'like',
#  'good',
#  'then',
#  'he',
#  'there',
#  'was',
#  'got',
#  'its',
#  'time',
#  'come',
#  'love',
#  'only',
#  'send',
#  'want',
#  'text',
#  'txt',
#  'one',
#  'as',
#  'about',
#  'by',
#  'home',
#  'going',
#  'sorry',
#  'she',
#  'today',
#  'stop',
#  'see',
#  'our',
#  'need',
#  'back',
#  'don',
#  'lor',
#  'still',
#  'mobile',
#  'dont',
#  'pls',
#  'think',
#  'later',
#  'reply',
#  'tell',
#  'been',
#  'any',
#  'da',
#  'hi',
#  'take',
#  'please',
#  'dear',
#  'well',
#  'new',
#  'some',
#  'week',
#  'phone',
#  'they',
#  'her',
#  'did',
#  'who',
#  'here',
#  'much',
#  'has',
#  'great',
#  'hey',
#  'night',
#  'hope',
#  'an',
#  'claim',
#  'ì_',
#  'him',
#  'where',
#  're',
#  'more',
#  'msg',
#  'oh',
#  'happy',
#  'too',
#  'wat',
#  'yes',
#  'message',
#  'had',
#  'make',
#  'www',
#  'way',
#  'work',
#  'should',
#  'give',
#  'number',
#  'say',
#  'tomorrow',
#  'won',
#  'said',
#  'right',
#  've',
#  'why',
#  'cash',
#  'really',
#  'prize',
#  'ask',
#  'after',
#  'win',
#  'find',
#  'already',
#  'babe',
#  'meet',
#  'im',
#  'would',
#  'life',
#  'uk',
#  'let',
#  'amp',
#  'every',
#  'doing',
#  'miss',
#  'cos',
#  'yeah',
#  'morning',
#  'urgent',
#  'sent',
#  'care',
#  'them',
#  'sure',
#  'com',
#  'anything',
#  'min',
#  'thanks',
#  'keep',
#  'very',
#  'someone',
#  'lol',
#  'box',
#  'pick',
#  'buy',
#  'last',
#  'before',
#  'nokia',
#  'us',
#  'contact',
#  'even',
#  'over',
#  'also',
#  'help',
#  'something',
#  'went',
#  'around',
#  'again',
#  'cant',
#  'chat',
#  'wait',
#  'gonna',
#  'first',
#  'feel',
#  'off',
#  'tonight',
#  'place',
#  'service',
#  'things',
#  'pm',
#  'per',
#  'co',
#  'tone',
#  'always',
#  'gud',
#  'mins',
#  'nice',
#  'many',
#  'his',
#  'thing',
#  'name',
#  'other',
#  'holiday',
#  'next',
#  'st',
#  'could',
#  'which',
#  'wish',
#  'customer',
#  'friends',
#  'sleep',
#  'money',
#  'best',
#  'same',
#  'hello',
#  'ya',
#  'soon',
#  'may',
#  'coming',
#  'wan',
#  'were',
#  'dun',
#  'late',
#  'friend',
#  'sms',
#  'people',
#  'down',
#  'smile',
#  'special',
#  'live',
#  'th',
#  'try',
#  'told',
#  'didn',
#  'god',
#  'leave',
#  'waiting',
#  'fine',
#  'use',
#  'heart',
#  'yet',
#  'guaranteed',
#  'done',
#  'class',
#  'yup',
#  'pobox',
#  'person',
#  'year',
#  'line',
#  'ìï',
#  'ppm',
#  'thought',
#  'cs',
#  'few',
#  'talk',
#  'thats',
#  'draw',
#  'half',
#  'stuff',
#  'thk',
#  'haha',
#  'sir',
#  'play',
#  'having',
#  'getting',
#  'wk',
#  'big',
#  'than',
#  'days',
#  'receive',
#  'bit',
#  'dat',
#  'lunch',
#  'house',
#  'man',
#  'word',
#  'meeting',
#  'awarded',
#  'problem',
#  'better',
#  'car',
#  'job',
#  'real',
#  'yo',
#  'check',
#  'end',
#  'finish',
#  'ready',
#  'eat',
#  'birthday',
#  'ill',
#  'trying',
#  'chance',
#  'being',
#  'po',
#  'month',
#  'cool',
#  'lot',
#  'start',
#  'called',
#  'guess',
#  'might',
#  'latest',
#  'ever',
#  'jus',
#  'enjoy',
#  'offer',
#  'mind',
#  'camera',
#  'wanna',
#  'long',
#  'girl',
#  'another',
#  'nothing',
#  'dinner',
#  'never',
#  'watch',
#  'lar',
#  'guys',
#  'world',
#  'hrs',
#  'cost',
#  'landline',
#  'weekend',
#  'shit',
#  'age',
#  'shall',
#  'luv',
#  'quite',
#  'fun',
#  'two',
#  'bad',
#  'into',
#  'aight',
#  'xxx',
#  'pa',
#  'because',
#  'apply',
#  'sweet',
#  'hear',
#  'tones',
#  'probably',
#  'nd',
#  'speak',
#  'bed',
#  'account',
#  'plan',
#  'ringtone',
#  'shopping',
#  'thanx',
#  'award',
#  'leh',
#  'nite',
#  'once',
#  'kiss',
#  'rate',
#  'left',
#  'afternoon',
#  'video',
#  'bt',
#  'watching',
#  'pay',
#  'texts',
#  'den',
#  'wife',
#  'look',
#  'missing',
#  'entry',
#  'thank',
#  'hour',
#  'everything',
#  'xx',
#  'sat',
#  'ah',
#  'selected',
#  'easy',
#  'remember',
#  'collection',
#  'shows',
#  'working',
#  'goes',
#  'minutes',
#  'maybe',
#  'since',
#  'wont',
#  'forgot',
#  'network',
#  'able',
#  'tv',
#  'orange',
#  'didnt',
#  'early',
#  'code',
#  'put',
#  'face',
#  'calls',
#  'dis',
#  'liao',
#  'anyway',
#  'enough',
#  'between',
#  'most',
#  'part',
#  'bus',
#  'actually',
#  'must',
#  'sexy',
#  'does',
#  'til',
#  'true',
#  'mail',
#  'gift',
#  'de',
#  'baby',
#  'fuck',
#  'asked',
#  'missed',
#  'show',
#  'tmr',
#  'reach',
#  'guy',
#  'though',
#  'makes',
#  'until',
#  'evening',
#  'haven',
#  'room',
#  'alright',
#  'looking',
#  'office',
#  'dunno',
#  'those',
#  'town',
#  'mob',
#  'details',
#  'boy',
#  'away',
#  'while',
#  'valid',
#  'shop',
#  'okay',
#  'join',
#  'hav',
#  'wanted',
#  'saw',
#  'years',
#  'game',
#  'dad',
#  'wif',
#  'important',
#  'trip',
#  'these',
#  'weekly',
#  'abt',
#  'messages',
#  'princess',
#  'made',
#  'without',
#  'update',
#  'plz',
#  'sae',
#  'poly',
#  'wake',
#  'stay',
#  'says',
#  'little',
#  'times',
#  'xmas',
#  'sad',
#  'school',
#  'smiling',
#  'words',
#  'goin',
#  'hurt',
#  'address',
#  'yesterday',
#  'dude',
#  'friendship',
#  'music',
#  'await',
#  'yourself',
#  'plus',
#  'pain',
#  'means',
#  'yours',
#  'came',
#  'change',
#  'bonus',
#  'else',
#  'ring',
#  'net',
#  'games',
#  'comes',
#  'answer',
#  'saying',
#  'making',
#  'havent',
#  'club',
#  'vouchers',
#  'national',
#  'wants',
#  'post',
#  'todays',
#  'noe',
#  'nt',
#  'busy',
#  'dreams',
#  'wot',
#  'date',
#  'bring',
#  'id',
#  'either',
#  'charge',
#  'wen',
#  'haf',
#  'price',
#  'run',
#  'collect',
#  'pounds',
#  'coz',
#  'hours',
#  'worry',
#  'ard',
#  'decimal',
#  'lose',
#  'lei',
#  'colour',
#  'knw',
#  'old',
#  'online',
#  'leaving',
#  'pic',
#  'double',
#  'sch',
#  'top',
#  'together',
#  'wid',
#  'both',
#  'walk',
#  'book',
#  'attempt',
#  'till',
#  'okie',
#  'juz',
#  'drink',
#  'second',
#  'hot',
#  'mean',
#  'hair',
#  'family',
#  'story',
#  'sleeping',
#  'gr',
#  'land',
#  'news',
#  'food',
#  'worth',
#  'brother',
#  'movie',
#  'huh',
#  'info',
#  'set',
#  'everyone',
#  'finished',
#  'dating',
#  'oso',
#  'bored',
#  'took',
#  'drive',
#  'delivery',
#  'order',
#  'thinking',
#  'calling',
#  'question',
#  'choose',
#  'opt',
#  'break',
#  'tho',
#  'optout',
#  'pub',
#  'tried',
#  'company',
#  'whats',
#  'angry',
#  'carlos',
#  'started',
#  'happen',
#  'pics',
#  'driving',
#  'operator',
#  'taking',
#  'treat',
#  'mum',
#  'rite',
#  'congrats',
#  'forget',
#  'feeling',
#  'sun',
#  'sister',
#  'http',
#  'mths',
#  'voucher',
#  'prob',
#  'far',
#  'mine',
#  'open',
#  'doesn',
#  'beautiful',
#  'aft',
#  'smoke',
#  'hard',
#  'tomo',
#  'awesome',
#  'gbp',
#  'pretty',
#  'loving',
#  'bank',
#  'found',
#  'alone',
#  'fast',
#  'private',
#  'lets',
#  'drop',
#  'wit',
#  'winner',
#  'available',
#  'unsubscribe',
#  'touch',
#  'sis',
#  'whatever',
#  'services',
#  'full',
#  'points',
#  'anytime',
#  'ha',
#  'search',
#  'gd',
#  'sea',
#  'outside',
#  'gone',
#  'boytoy',
#  'chikku',
#  'anyone',
#  'head',
#  'savamob',
#  'fone',
#  'wonderful',
#  'takes',
#  'neva',
#  'christmas',
#  'college',
#  'final',
#  'needs',
#  'whole',
#  'darlin',
#  'wil',
#  'minute',
#  'frnd',
#  'nope',
#  'lucky',
#  'course',
#  'believe',
#  'each',
#  'test',
#  'statement',
#  'tel',
#  'frm',
#  'read',
#  'card',
#  'hows',
#  'visit',
#  'eh',
#  'crazy',
#  'yr',
#  'msgs',
#  'download',
#  'least',
#  'mom',
#  'lots',
#  'weeks',
#  'sunday',
#  'finally',
#  'girls',
#  'felt',
#  'cum',
#  'fri',
#  'wrong',
#  'listen',
#  'ni',
#  'reading',
#  'meant',
#  'telling',
#  'close',
#  'understand',
#  'congratulations',
#  'suite',
#  'etc',
#  'saturday',
#  'na',
#  'project',
#  'fr',
#  'hold',
#  'side',
#  'cause',
#  'sounds',
#  'lesson',
#  'mu',
#  'fancy',
#  'snow',
#  'india',
#  'email',
#  'content',
#  'nyt',
#  'type',
#  'isn',
#  'blue',
#  'mates',
#  'hl',
#  'case',
#  'kind',
#  'their',
#  'jay',
#  'park',
#  'auction',
#  'reason',
#  'hit',
#  'ltd',
#  'tired',
#  'thinks',
#  'song',
#  'sk',
#  'unlimited',
#  'expires',
#  'correct',
#  'feels',
#  'mobileupd',
#  'direct',
#  'tot',
#  'die',
#  'supposed',
#  'party',
#  'goodmorning',
#  'support',
#  'ish',
#  'march',
#  'welcome',
#  'happened',
#  'currently',
#  'earlier',
#  'identifier',
#  'paper',
#  'mate',
#  'bslvyl',
#  'confirm',
#  'secret',
#  'eve',
#  'hand',
#  'press',
#  'met',
#  'camcorder',
#  'freemsg',
#  'laptop',
#  'light',
#  'row',
#  'police',
#  'wow',
#  'caller',
#  'happiness',
#  'frnds',
#  'cut',
#  'ex',
#  'wonder',
#  'û_',
#  'wasn',
#  'offers',
#  'tc',
#  'mayb',
#  'friday',
#  'dnt',
#  'complimentary',
#  'couple',
#  'numbers',
#  'dogging',
#  'convey',
#  'decided',
#  'ago',
#  'exam',
#  'lands',
#  'months',
#  'wana',
#  'darren',
#  'blood',
#  'parents',
#  'valued',
#  'ugh',
#  'wine',
#  'questions',
#  'rakhesh',
#  'askd',
#  'ends',
#  'sending',
#  'lost',
#  'knew',
#  'area',
#  'seen',
#  'talking',
#  'sound',
#  'hmmm',
#  'worried',
#  'almost',
#  'comp',
#  'rates',
#  'entered',
#  'within',
#  'std',
#  'lovely',
#  'less',
#  'ringtones',
#  'computer',
#  'rental',
#  'across',
#  'quiz',
#  'monday',
#  'via',
#  'grins',
#  'wkly',
#  'credit',
#  'hee',
#  'immediately',
#  'store',
#  'reveal',
#  'wq',
#  'bout',
#  'heard',
#  'stupid',
#  'fucking',
#  'picking',
#  'gn',
#  'abiola',
#  'rest',
#  'smth',
#  'nobody',
#  'gets',
#  'discount',
#  'rply',
#  'oredi',
#  'uncle',
#  'ive',
#  'booked',
#  'hmv',
#  'custcare',
#  'difficult',
#  'un',
#  'shower',
#  'enter',
#  'txting',
#  'yrs',
#  'hoping',
#  'motorola',
#  'gettin',
#  'ts',
#  'wap',
#  'mobiles',
#  'voice',
#  'luck',
#  'bcoz',
#  'possible',
#  'sex',
#  'brings',
#  'gas',
#  'al',
#  'rent',
#  'rain',
#  'near',
#  'gotta',
#  'seeing',
#  'log',
#  'mm',
#  'somewhere',
#  'invited',
#  'match',
#  'doin',
#  'information',
#  'rock',
#  'phones',
#  'unless',
#  'itself',
#  'balance',
#  'slow',
#  'del',
#  'gym',
#  'yar',
#  'situation',
#  'chennai',
#  'leaves',
#  'cheap',
#  'ten',
#  'ûò',
#  'red',
#  'hw',
#  'flag',
#  'wc',
#  'worries',
#  'ac',
#  'mrng',
#  'accept',
#  'link',
#  'usf',
#  'ans',
#  'warm',
#  'glad',
#  'oops',
#  'none',
#  'pass',
#  'swing',
#  'reward',
#  'point',
#  'hospital',
#  'rs',
#  'mr',
#  'charity',
#  'nah',
#  'lemme',
#  'wishing',
#  'ip',
#  'anymore',
#  'sort',
#  'staying',
#  'kate',
#  'max',
#  'through',
#  'ho',
#  'ar',
#  'fact',
#  'lovable',
#  'pray',
#  'drugs',
#  'cr',
#  'deal',
#  'save',
#  'starting',
#  'water',
#  'player',
#  'fault',
#  'hungry',
#  'kick',
#  'ass',
#  'mrt',
#  'catch',
#  'future',
#  'callertune',
#  'getzed',
#  'longer',
#  'txts',
#  'ldew',
#  'complete',
#  'pizza',
#  'wondering',
#  'laugh',
#  'slowly',
#  'cd',
#  'slept',
#  'ntt',
#  'ipod',
#  'bx',
#  'eg',
#  'admirer',
#  'pete',
#  'merry',
#  'used',
#  'noon',
#  'charged',
#  'cancel',
#  'doctor',
#  'ending',
#  'england',
#  'remove',
#  'loves',
#  'lover',
#  'redeemed',
#  'em',
#  'mode',
#  'forever',
#  'extra',
#  ...]

# %%
len(w2v_model.wv['free'])
# Out:
# 100

# %%
X_test
# Out:
# 5109                                                                                   [oh, you, got, many]
# 4929    [hi, the, sexychat, girls, are, waiting, for, you, to, text, them, text, now, for, great, night,...
# 4719              [forgot, to, tell, ì_, smth, can, ì_, like, number, the, sections, so, that, it, clearer]
# 1333                                                                 [oh, icic, lor, den, meet, other, day]
# 4693    [pls, give, her, the, food, preferably, pap, very, slowly, with, loads, of, sugar, you, can, tak...
#                                                        ...
# 939     [better, made, up, for, friday, and, stuffed, myself, like, pig, yesterday, now, feel, bleh, but...
# 4140    [beautiful, truth, expression, of, the, face, could, be, seen, by, everyone, but, the, depressio...
# 5150    [happy, new, year, to, and, ur, family, may, this, new, year, bring, happiness, stability, and, ...
# 4811                                                    [fyi, at, usf, now, swing, by, the, room, whenever]
# 4004                                                            [ow, dey, paid, thousad, told, would, call]
# Name: text_clean, Length: 1115, dtype: object

# %%
max_len = max(len(ls) for ls in X_test) 
max_len

w2v_vect = [np.array([w2v_model.wv[i] if i in w2v_model.wv.index_to_key else np.zeros(100) for i in ls] + [np.zeros(100)] * (max_len - len(ls))) for ls in X_test]

# %%
# w2v_vect = np.vstack([np.array([w2v_model.wv[i] for i in ls if i in w2v_model.wv.index_to_key] or [np.zeros(100)]) for ls in X_test])
# w2v_vect = np.array([np.array([w2v_model.wv[i] for i in ls if i in w2v_model.wv.index_to_key]) for ls in X_test])
w2v_vect = [np.array([w2v_model.wv[i] for i in ls if i in w2v_model.wv.index_to_key]) for ls in X_test]
w2v_vect[0:2]
# Out:
# [array([[-0.19997314,  0.29739287,  0.02854843,  0.04640778,  0.10774346,
#          -0.5791091 ,  0.26312023,  0.7571186 , -0.29510304, -0.348881  ,
#          -0.19531594, -0.6796173 , -0.02252132,  0.16435447,  0.19086671,
#          -0.29333663,  0.05761117, -0.45026943, -0.02443293, -0.7126424 ,
#           0.26291877,  0.29872987,  0.14668882, -0.20118624, -0.07120603,
#           0.03741152, -0.3581561 , -0.28194207, -0.44366527,  0.0718427 ,
#           0.31125015,  0.10162631,  0.15961413, -0.44784734, -0.21245445,
#           0.43474838, -0.08147884, -0.25366697, -0.2514893 , -0.67671657,
#           0.12074463, -0.4324356 , -0.27451602,  0.04734866,  0.35193917,
#          -0.0981661 , -0.22302508, -0.07424755,  0.16763717,  0.22930141,
#           0.04732389, -0.32749227, -0.01273228, -0.09027507, -0.06575549,
#           0.05605656,  0.24350779, -0.10795879, -0.4206674 ,  0.21648133,
#           0.11331315,  0.078687  ,  0.07727103, -0.11739239, -0.38242498,
#           0.40158165,  0.07309917,  0.47994065, -0.43321598,  0.4854343 ,
#          -0.18479088,  0.29062444,  0.5074298 , -0.10317438,  0.50984496,
#           0.24135171,  0.04805781, -0.1226972 , -0.23568763, -0.10318975,
#          -0.1366053 ,  0.00938821, -0.4791345 ,  0.45260802, -0.25153422,
#          -0.11014653,  0.2721654 ,  0.45302606,  0.49156713,  0.10295949,
#           0.5277712 ,  0.24646133,  0.06443659,  0.10732239,  0.66367465,
#           0.43093082,  0.24382587, -0.3366895 ,  0.12501633, -0.1974861 ],
#         [-0.269839  ,  0.39904535,  0.05499188,  0.12601122,  0.1564842 ,
#          -0.8649722 ,  0.40138578,  1.1225853 , -0.4710573 , -0.5502522 ,
#          -0.24284308, -0.97261524, -0.01694528,  0.26884994,  0.25620827,
#          -0.445441  ,  0.12624657, -0.68090564, -0.06621087, -1.089105  ,
#           0.45343766,  0.45232582,  0.23699872, -0.346344  , -0.09931201,
#           0.01668845, -0.5041723 , -0.35248777, -0.6577583 ,  0.10182314,
#           0.4317733 ,  0.16181588,  0.25165254, -0.6592497 , -0.30198273,
#           0.61702156, -0.12031864, -0.38955042, -0.35087368, -1.0180542 ,
#           0.17135248, -0.62986267, -0.426288  ,  0.05569185,  0.49281645,
#          -0.1294663 , -0.36217472, -0.08213907,  0.2485096 ,  0.34147808,
#           0.04142605, -0.48074487, -0.02418787, -0.16329855, -0.05249869,
#           0.08498614,  0.3655464 , -0.16280046, -0.65705925,  0.36182594,
#           0.12751761,  0.1077986 ,  0.12794347, -0.17392485, -0.55907077,
#           0.6042293 ,  0.11430275,  0.7170459 , -0.6322534 ,  0.70558023,
#          -0.25936195,  0.40180767,  0.6988064 , -0.1569564 ,  0.7520435 ,
#          -0.15422699,  0.22742318,  0.3943829 , -0.07821209,  0.40171075,
#           0.19220582,  0.04027266, -0.08340868, -0.19415389, -0.08104824,
#          -0.09968659,  0.00937396, -0.3769387 ,  0.36467052, -0.20417897,
#          -0.08490827,  0.21673408,  0.35328338,  0.37571323,  0.08597329,
#           0.4366362 ,  0.19416581,  0.06538378,  0.07269459,  0.5309846 ,
#           0.33636138,  0.1939313 , -0.2626244 ,  0.10062025, -0.14188696]],
#        dtype=float32),
#  array([[-0.19191526,  0.32412338,  0.02486513, ..., -0.3602902 ,
#           0.12310105, -0.21817376],
#         [-0.33442357,  0.51922315,  0.03836976, ..., -0.60469514,
#           0.24635863, -0.32817438],
#         [-0.06433529,  0.08853772,  0.00157025, ..., -0.08951876,
#           0.03413246, -0.05710048],
#         ...,
#         [-0.32272148,  0.46158662,  0.08569641, ..., -0.52799654,
#           0.20239745, -0.2266375 ],
#         [-0.27391285,  0.40957895,  0.04125543, ..., -0.50302935,
#           0.18349615, -0.24339212],
#         [-0.19714476,  0.272522  ,  0.04158012, ..., -0.32352448,
#           0.13081503, -0.16561933]], dtype=float32)]

# %%
# Why is the length of the sentence different than the length of the sentence vector?
for i, v in enumerate(w2v_vect):
    print(len(X_test.iloc[i]), len(v))
# Out:
# 4 4
# 23 22
# 15 13
# 7 6
# 30 28
# 13 12
# 6 6
# 5 5
# 15 14
# 9 7
# 25 20
# 25 22
# 4 4
# 7 7
# 19 19
# 35 35
# 4 3
# 16 13
# 8 8
# 15 9
# 18 16
# 24 21
# 7 7
# 16 15
# 20 20
# 22 20
# 15 13
# 28 28
# 7 4
# 20 19
# 7 5
# 19 16
# 27 25
# 6 6
# 16 12
# 14 13
# 4 4
# 9 9
# 25 25
# 9 6
# 7 7
# 5 5
# 8 7
# 8 8
# 19 12
# 18 17
# 7 6
# 6 6
# 25 25
# 27 26
# 13 13
# 21 19
# 14 12
# 5 4
# 16 13
# 19 19
# 5 2
# 15 14
# 10 9
# 7 7
# 32 31
# 5 5
# 6 5
# 28 24
# 6 6
# 18 14
# 10 10
# 6 5
# 29 29
# 15 15
# 29 28
# 4 1
# 28 21
# 2 2
# 2 0
# 15 14
# 18 16
# 10 7
# 19 17
# 8 8
# 25 19
# 24 23
# 7 2
# 25 24
# 28 26
# 4 4
# 13 13
# 9 9
# 5 5
# 6 6
# 25 23
# 7 6
# 5 5
# 10 9
# 16 13
# 20 20
# 21 18
# 30 28
# 13 13
# 14 13
# 9 9
# 16 15
# 5 5
# 8 8
# 20 19
# 8 8
# 9 7
# 29 26
# 7 7
# 9 8
# 7 7
# 11 9
# 20 19
# 13 12
# 21 21
# 17 9
# 4 4
# 7 6
# 58 53
# 42 38
# 6 4
# 25 24
# 21 18
# 9 9
# 2 2
# 9 9
# 8 7
# 9 8
# 6 6
# 11 11
# 12 11
# 17 16
# 7 7
# 6 3
# 13 13
# 7 6
# 2 2
# 5 5
# 22 21
# 18 15
# 14 11
# 6 6
# 6 5
# 9 9
# 5 4
# 7 7
# 17 17
# 16 16
# 7 7
# 14 11
# 7 5
# 5 4
# 11 11
# 15 14
# 21 14
# 7 5
# 7 7
# 12 11
# 9 8
# 5 5
# 4 4
# 4 4
# 24 20
# 13 13
# 19 18
# 9 9
# 7 6
# 8 7
# 11 9
# 26 23
# 11 11
# 3 3
# 16 15
# 25 24
# 8 6
# 8 7
# 14 13
# 24 20
# 7 7
# 16 14
# 6 5
# 25 25
# 9 8
# 9 9
# 18 17
# 14 13
# 23 23
# 11 10
# 8 6
# 5 3
# 6 5
# 24 18
# 23 19
# 9 7
# 8 8
# 8 8
# 38 36
# 25 24
# 27 27
# 21 20
# 44 41
# 2 2
# 8 8
# 26 26
# 17 16
# 5 5
# 24 23
# 13 10
# 31 28
# 12 12
# 7 7
# 6 6
# 23 23
# 8 8
# 9 9
# 20 20
# 16 13
# 23 20
# 4 4
# 4 4
# 5 4
# 7 6
# 4 4
# 18 17
# 26 25
# 3 3
# 7 6
# 20 20
# 16 14
# 5 4
# 19 18
# 10 10
# 10 10
# 15 14
# 9 9
# 4 4
# 7 7
# 4 3
# 5 5
# 22 22
# 7 5
# 18 16
# 7 7
# 4 4
# 18 18
# 7 6
# 3 3
# 13 12
# 10 9
# 22 20
# 18 11
# 19 17
# 17 17
# 8 8
# 19 17
# 24 22
# 14 12
# 17 16
# 22 19
# 4 4
# 7 5
# 17 13
# 6 6
# 15 15
# 5 5
# 13 10
# 11 11
# 11 11
# 10 10
# 3 3
# 29 29
# 13 13
# 9 8
# 27 24
# 32 28
# 7 6
# 8 8
# 12 10
# 8 8
# 17 17
# 6 5
# 4 4
# 6 6
# 19 18
# 10 10
# 7 7
# 21 21
# 23 22
# 9 8
# 10 10
# 8 7
# 3 3
# 5 5
# 6 6
# 24 23
# 29 28
# 23 21
# 18 17
# 10 9
# 8 8
# 15 14
# 8 8
# 12 11
# 7 6
# 12 11
# 6 3
# 14 12
# 26 26
# 6 6
# 6 6
# 4 4
# 19 18
# 24 24
# 7 6
# 8 7
# 29 28
# 21 21
# 8 6
# 10 10
# 16 15
# 4 4
# 23 23
# 25 25
# 23 22
# 18 18
# 5 5
# 6 6
# 19 18
# 26 26
# 14 13
# 19 15
# 8 7
# 23 23
# 24 20
# 26 24
# 21 17
# 9 9
# 7 5

# %%
# Compute sentence vectors by averaging the word vectors for the words contained in the sentence
w2v_vect_avg = []

for vect in w2v_vect:
    if len(vect)!=0:
        w2v_vect_avg.append(vect.mean(axis=0))
    else:
        w2v_vect_avg.append(np.zeros(100))

# %%
# Are our sentence vector lengths consistent?
for i, v in enumerate(w2v_vect_avg):
    print(len(X_test.iloc[i]), len(v))
# Out:
# 4 100
# 23 100
# 15 100
# 7 100
# 30 100
# 13 100
# 6 100
# 5 100
# 15 100
# 9 100
# 25 100
# 25 100
# 4 100
# 7 100
# 19 100
# 35 100
# 4 100
# 16 100
# 8 100
# 15 100
# 18 100
# 24 100
# 7 100
# 16 100
# 20 100
# 22 100
# 15 100
# 28 100
# 7 100
# 20 100
# 7 100
# 19 100
# 27 100
# 6 100
# 16 100
# 14 100
# 4 100
# 9 100
# 25 100
# 9 100
# 7 100
# 5 100
# 8 100
# 8 100
# 19 100
# 18 100
# 7 100
# 6 100
# 25 100
# 27 100
# 13 100
# 21 100
# 14 100
# 5 100
# 16 100
# 19 100
# 5 100
# 15 100
# 10 100
# 7 100
# 32 100
# 5 100
# 6 100
# 28 100
# 6 100
# 18 100
# 10 100
# 6 100
# 29 100
# 15 100
# 29 100
# 4 100
# 28 100
# 2 100
# 2 100
# 15 100
# 18 100
# 10 100
# 19 100
# 8 100
# 25 100
# 24 100
# 7 100
# 25 100
# 28 100
# 4 100
# 13 100
# 9 100
# 5 100
# 6 100
# 25 100
# 7 100
# 5 100
# 10 100
# 16 100
# 20 100
# 21 100
# 30 100
# 13 100
# 14 100
# 9 100
# 16 100
# 5 100
# 8 100
# 20 100
# 8 100
# 9 100
# 29 100
# 7 100
# 9 100
# 7 100
# 11 100
# 20 100
# 13 100
# 21 100
# 17 100
# 4 100
# 7 100
# 58 100
# 42 100
# 6 100
# 25 100
# 21 100
# 9 100
# 2 100
# 9 100
# 8 100
# 9 100
# 6 100
# 11 100
# 12 100
# 17 100
# 7 100
# 6 100
# 13 100
# 7 100
# 2 100
# 5 100
# 22 100
# 18 100
# 14 100
# 6 100
# 6 100
# 9 100
# 5 100
# 7 100
# 17 100
# 16 100
# 7 100
# 14 100
# 7 100
# 5 100
# 11 100
# 15 100
# 21 100
# 7 100
# 7 100
# 12 100
# 9 100
# 5 100
# 4 100
# 4 100
# 18 100
# 17 100
# 24 100
# 27 100
# 9 100
# 24 100
# 49 100
# 21 100
# 18 100
# 6 100
# 5 100
# 9 100
# 10 100
# 6 100
# 7 100
# 23 100
# 4 100
# 6 100
# 8 100
# 8 100
# 9 100
# 21 100
# 16 100
# 4 100
# 4 100
# 28 100
# 10 100
# 10 100
# 14 100
# 9 100
# 5 100
# 14 100
# 9 100
# 7 100
# 37 100
# 28 100
# 17 100
# 30 100
# 4 100
# 6 100
# 19 100
# 9 100
# 25 100
# 18 100
# 11 100
# 5 100
# 24 100
# 14 100
# 10 100
# 46 100
# 13 100
# 5 100
# 27 100
# 10 100
# 17 100
# 10 100
# 7 100
# 23 100
# 7 100
# 6 100
# 15 100
# 5 100
# 12 100
# 7 100
# 4 100
# 6 100
# 17 100
# 7 100
# 9 100
# 13 100
# 10 100
# 9 100
# 20 100
# 6 100
# 23 100
# 12 100
# 8 100
# 5 100
# 17 100
# 12 100
# 7 100
# 9 100
# 20 100
# 30 100
# 22 100
# 16 100
# 8 100
# 5 100
# 6 100
# 5 100
# 14 100
# 6 100
# 14 100
# 4 100
# 22 100
# 4 100
# 16 100
# 21 100
# 25 100
# 5 100
# 25 100
# 9 100
# 5 100
# 7 100
# 21 100
# 9 100
# 11 100
# 21 100
# 29 100
# 25 100
# 12 100
# 27 100
# 8 100
# 1 100
# 7 100
# 26 100
# 6 100
# 20 100
# 7 100
# 8 100
# 17 100
# 22 100
# 23 100
# 20 100
# 14 100
# 12 100
# 18 100
# 9 100
# 12 100
# 0 100
# 27 100
# 6 100
# 7 100
# 30 100
# 25 100
# 10 100
# 1 100
# 5 100
# 4 100
# 26 100
# 10 100
# 3 100
# 5 100
# 9 100
# 5 100
# 24 100
# 24 100
# 5 100
# 24 100
# 5 100
# 7 100
# 11 100
# 22 100
# 5 100
# 4 100
# 101 100
# 14 100
# 14 100
# 11 100
# 27 100
# 6 100
# 10 100
# 9 100
# 26 100
# 12 100
# 10 100
# 6 100
# 6 100
# 22 100
# 6 100
# 4 100
# 17 100
# 5 100
# 28 100
# 7 100
# 11 100
# 17 100
# 16 100
# 23 100
# 8 100
# 24 100
# 8 100
# 26 100
# 5 100
# 11 100
# 16 100
# 9 100
# 5 100
# 27 100
# 7 100
# 12 100
# 17 100
# 13 100
# 12 100
# 15 100
# 5 100
# 8 100
# 22 100
# 31 100
# 22 100
# 6 100
# 6 100
# 12 100
# 18 100
# 7 100
# 5 100
# 15 100
# 26 100
# 5 100
# 17 100
# 7 100
# 17 100
# 10 100
# 12 100
# 8 100
# 23 100
# 7 100
# 11 100
# 4 100
# 5 100
# 11 100
# 42 100
# 9 100
# 8 100
# 6 100
# 8 100
# 12 100
# 36 100
# 22 100
# 22 100
# 15 100
# 5 100
# 9 100
# 9 100
# 17 100
# 6 100
# 6 100
# 8 100
# 22 100
# 5 100
# 3 100
# 23 100
# 26 100
# 10 100
# 4 100
# 14 100
# 5 100
# 2 100
# 21 100
# 8 100
# 7 100
# 8 100
# 7 100
# 11 100
# 9 100
# 8 100
# 30 100
# 7 100
# 19 100
# 9 100
# 7 100
# 21 100
# 9 100
# 5 100
# 5 100
# 6 100
# 18 100
# 3 100
# 4 100
# 6 100
# 19 100
# 12 100
# 4 100
# 28 100
# 5 100
# 18 100
# 5 100
# 21 100
# 23 100
# 19 100
# 15 100
# 21 100
# 16 100
# 7 100
# 13 100
# 7 100
# 6 100
# 5 100
# 7 100
# 28 100
# 13 100
# 16 100
# 5 100
# 20 100
# 16 100
# 16 100
# 7 100
# 8 100
# 19 100
# 20 100
# 6 100
# 19 100
# 6 100
# 15 100
# 9 100
# 8 100
# 16 100
# 12 100
# 24 100
# 31 100
# 7 100
# 9 100
# 5 100
# 12 100
# 14 100
# 9 100
# 6 100
# 10 100
# 8 100
# 6 100
# 18 100
# 6 100
# 22 100
# 14 100
# 25 100
# 10 100
# 6 100
# 37 100
# 29 100
# 17 100
# 21 100
# 24 100
# 9 100
# 3 100
# 46 100
# 12 100
# 77 100
# 9 100
# 7 100
# 8 100
# 9 100
# 22 100
# 1 100
# 5 100
# 21 100
# 28 100
# 5 100
# 12 100
# 5 100
# 25 100
# 5 100
# 7 100
# 5 100
# 6 100
# 5 100
# 13 100
# 2 100
# 23 100
# 26 100
# 9 100
# 30 100
# 20 100
# 26 100
# 14 100
# 5 100
# 8 100
# 12 100
# 13 100
# 6 100
# 23 100
# 5 100
# 14 100
# 16 100
# 24 100
# 6 100
# 14 100
# 7 100
# 30 100
# 21 100
# 5 100
# 4 100
# 7 100
# 8 100
# 27 100
# 29 100
# 6 100
# 19 100
# 22 100
# 23 100
# 8 100
# 17 100
# 13 100
# 8 100
# 24 100
# 8 100
# 26 100
# 15 100
# 22 100
# 10 100
# 8 100
# 11 100
# 16 100
# 9 100
# 4 100
# 25 100
# 14 100
# 8 100
# 27 100
# 15 100
# 17 100
# 21 100
# 12 100
# 8 100
# 31 100
# 12 100
# 19 100
# 6 100
# 12 100
# 17 100
# 30 100
# 12 100
# 6 100
# 6 100
# 13 100
# 24 100
# 24 100
# 9 100
# 13 100
# 20 100
# 9 100
# 4 100
# 26 100
# 9 100
# 12 100
# 23 100
# 11 100
# 25 100
# 4 100
# 8 100
# 14 100
# 12 100
# 6 100
# 23 100
# 11 100
# 14 100
# 11 100
# 81 100
# 11 100
# 8 100
# 7 100
# 13 100
# 7 100
# 4 100
# 21 100
# 13 100
# 3 100
# 6 100
# 15 100
# 23 100
# 4 100
# 20 100
# 8 100
# 11 100
# 7 100
# 8 100
# 4 100
# 22 100
# 8 100
# 6 100
# 14 100
# 30 100
# 11 100
# 5 100
# 11 100
# 7 100
# 20 100
# 9 100
# 17 100
# 4 100
# 5 100
# 13 100
# 8 100
# 23 100
# 10 100
# 30 100
# 23 100
# 23 100
# 5 100
# 14 100
# 8 100
# 1 100
# 15 100
# 44 100
# 4 100
# 15 100
# 5 100
# 9 100
# 5 100
# 23 100
# 29 100
# 30 100
# 7 100
# 17 100
# 9 100
# 15 100
# 11 100
# 9 100
# 6 100
# 16 100
# 6 100
# 7 100
# 5 100
# 21 100
# 23 100
# 12 100
# 23 100
# 27 100
# 1 100
# 8 100
# 15 100
# 6 100
# 14 100
# 25 100
# 21 100
# 13 100
# 13 100
# 8 100
# 9 100
# 7 100
# 15 100
# 8 100
# 27 100
# 13 100
# 5 100
# 6 100
# 18 100
# 12 100
# 16 100
# 14 100
# 8 100
# 14 100
# 18 100
# 22 100
# 13 100
# 10 100
# 4 100
# 6 100
# 9 100
# 6 100
# 4 100
# 9 100
# 12 100
# 7 100
# 8 100
# 8 100
# 24 100
# 7 100
# 23 100
# 12 100
# 18 100
# 10 100
# 7 100
# 2 100
# 12 100
# 22 100
# 14 100
# 8 100
# 13 100
# 19 100
# 11 100
# 5 100
# 22 100
# 50 100
# 13 100
# 10 100
# 23 100
# 5 100
# 7 100
# 6 100
# 9 100
# 17 100
# 9 100
# 28 100
# 5 100
# 12 100
# 9 100
# 14 100
# 8 100
# 17 100
# 9 100
# 8 100
# 19 100
# 17 100
# 6 100
# 6 100
# 24 100
# 10 100
# 8 100
# 9 100
# 17 100
# 9 100
# 14 100
# 17 100
# 11 100
# 30 100
# 12 100
# 26 100
# 29 100
# 4 100
# 23 100
# 18 100
# 12 100
# 13 100
# 14 100
# 5 100
# 13 100
# 17 100
# 6 100
# 10 100
# 18 100
# 29 100
# 20 100
# 6 100
# 4 100
# 6 100
# 14 100
# 25 100
# 7 100
# 6 100
# 22 100
# 22 100
# 25 100
# 5 100
# 6 100
# 6 100
# 13 100
# 7 100
# 7 100
# 7 100
# 25 100
# 14 100
# 6 100
# 46 100
# 8 100
# 22 100
# 24 100
# 5 100
# 8 100
# 8 100
# 5 100
# 21 100
# 6 100
# 11 100
# 12 100
# 26 100
# 24 100
# 7 100
# 8 100
# 15 100
# 16 100
# 16 100
# 19 100
# 5 100
# 10 100
# 23 100
# 29 100
# 6 100
# 9 100
# 29 100
# 55 100
# 11 100
# 10 100
# 7 100
# 6 100
# 28 100
# 13 100
# 5 100
# 4 100
# 8 100
# 13 100
# 21 100
# 30 100
# 27 100
# 7 100
# 19 100
# 8 100
# 27 100
# 21 100
# 6 100
# 7 100
# 4 100
# 26 100
# 4 100
# 24 100
# 7 100
# 8 100
# 10 100
# 10 100
# 12 100
# 8 100
# 6 100
# 6 100
# 8 100
# 26 100
# 10 100
# 12 100
# 9 100
# 15 100
# 8 100
# 31 100
# 4 100
# 14 100
# 5 100
# 4 100
# 3 100
# 6 100
# 9 100
# 17 100
# 8 100
# 30 100
# 10 100
# 6 100
# 9 100
# 22 100
# 11 100
# 7 100
# 10 100
# 11 100
# 9 100
# 2 100
# 25 100
# 3 100
# 14 100
# 9 100
# 8 100
# 9 100
# 15 100
# 30 100
# 10 100
# 5 100
# 29 100
# 5 100
# 15 100
# 22 100
# 8 100
# 19 100
# 11 100
# 8 100
# 12 100
# 5 100
# 21 100
# 12 100
# 32 100
# 29 100
# 14 100
# 12 100
# 12 100
# 23 100
# 19 100
# 11 100
# 14 100
# 31 100
# 3 100
# 16 100
# 22 100
# 16 100
# 3 100
# 13 100
# 16 100
# 6 100
# 6 100
# 8 100
# 12 100
# 8 100
# 33 100
# 18 100
# 13 100
# 24 100
# 13 100
# 19 100
# 9 100
# 7 100
# 8 100
# 11 100
# 26 100
# 11 100
# 3 100
# 16 100
# 25 100
# 8 100
# 8 100
# 14 100
# 24 100
# 7 100
# 16 100
# 6 100
# 25 100
# 9 100
# 9 100
# 18 100
# 14 100
# 23 100
# 11 100
# 8 100
# 5 100
# 6 100
# 24 100
# 23 100
# 9 100
# 8 100
# 8 100
# 38 100
# 25 100
# 27 100
# 21 100
# 44 100
# 2 100
# 8 100
# 26 100
# 17 100
# 5 100
# 24 100
# 13 100
# 31 100
# 12 100
# 7 100
# 6 100
# 23 100
# 8 100
# 9 100
# 20 100
# 16 100
# 23 100
# 4 100
# 4 100
# 5 100
# 7 100
# 4 100
# 18 100
# 26 100
# 3 100
# 7 100
# 20 100
# 16 100
# 5 100
# 19 100
# 10 100
# 10 100
# 15 100
# 9 100
# 4 100
# 7 100
# 4 100
# 5 100
# 22 100
# 7 100
# 18 100
# 7 100
# 4 100
# 18 100
# 7 100
# 3 100
# 13 100
# 10 100
# 22 100
# 18 100
# 19 100
# 17 100
# 8 100
# 19 100
# 24 100
# 14 100
# 17 100
# 22 100
# 4 100
# 7 100
# 17 100
# 6 100
# 15 100
# 5 100
# 13 100
# 11 100
# 11 100
# 10 100
# 3 100
# 29 100
# 13 100
# 9 100
# 27 100
# 32 100
# 7 100
# 8 100
# 12 100
# 8 100
# 17 100
# 6 100
# 4 100
# 6 100
# 19 100
# 10 100
# 7 100
# 21 100
# 23 100
# 9 100
# 10 100
# 8 100
# 3 100
# 5 100
# 6 100
# 24 100
# 29 100
# 23 100
# 18 100
# 10 100
# 8 100
# 15 100
# 8 100
# 12 100
# 7 100
# 12 100
# 6 100
# 14 100
# 26 100
# 6 100
# 6 100
# 4 100
# 19 100
# 24 100
# 7 100
# 8 100
# 29 100
# 21 100
# 8 100
# 10 100
# 16 100
# 4 100
# 23 100
# 25 100
# 23 100
# 18 100
# 5 100
# 6 100
# 19 100
# 26 100
# 14 100
# 19 100
# 8 100
# 23 100
# 24 100
# 26 100
# 21 100
# 9 100
# 7 100
